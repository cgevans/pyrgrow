# %%
import numpy as np
from scipy.spatial.distance import pdist, squareform

from math import pi  
from scipy.optimize import minimize
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.optimize import least_squares
import itertools


import multiprocessing
import functools
from scipy import io
import time
import cProfile

import GillespieTST_0501_rateupdate as TST

import rgrow

# Load all maps
JmatE,JmatN,J_friends,smaps = TST.load_interaction_matrices();

# common initialization
# max grid size
n=62
init_conf = [[0]* (n+2)] * (n+2) # one layer margin on all sides

# Load interaction matrix data
q = len(JmatE)  # number of species+1. 0 = solvent

# User defined parameters here:
beta = 1
params ={"JmatE": JmatE,"JmatN": JmatN, "J_friends": J_friends, "n":n, "q":q, \
         "save_config_every":1, "kf": 1e6, "a":7.2} #, "Gmc": 10*beta}

## Code to process patterns

# Run FFS from lambda_2 to a high lambda_n. 
    # Target fixed variance for each lambda_i
    # Compute Z factor and report actual nucleation rate in units of M/s
def prop_forward_constvar(Gse,M,cvar,prams):
    
    params = prams.copy()    
    params["Gse"]=Gse
    
    sys = rgrow.PyStaticKTAM.from_raw(params["conc_vec"],JmatE*Gse, JmatN.T*Gse)

    # maintain constant variance.
    # var/mean^2 ~ (1-p)/(pM).. which decreases as p \to 1.
    # p_next > p_now .. so lower variance in the future. 
    # Use p_{now} to compute the desired variance. 
    
    # L2 -> L3 and then Li -> Li+1
    L_configs = [0] * 500
    pf_vec=[0]*500

    # Set up the special initial ratchet L2 -> L3 (dimers to trimers)
    L_configs[3],fin_size,z = TST.special_prop_L2_2_Lp_target(M,[3],sys,params);  pf_vec[3] = M/len(fin_size)
    print('z =',z)
    pf_vec[2] = (params["kf"]*z*np.exp(-2*params["a"]))


    Mnew = M
    
    lambda_sizes = list(range(3,100))

    overall_start_time = time.time()
    pf_vec_coll=[]
    for idx,init_size in enumerate(lambda_sizes[:-1]):
        target_size = lambda_sizes[idx+1]
        start_time = time.time()

        L_configs[target_size],fin_sze = TST.prop_Li_2_Lip1_targetC(L_configs[init_size],Mnew,[target_size],sys,params)        
        pf_vec[target_size] = Mnew/len(fin_sze)
                
        
        # compute Mnew to have a fixed variance
        Mnew = max(int((1-pf_vec[target_size])/(cvar)),50) 
        #print(Mnew)
        
        #print('pf(',init_size,'|',target_size,') = ',pf_vec[target_size], ' : Time = ', np.ceil(time.time()-start_time),' s')        

         # while the mean of last 4 values were < 0.97
        if np.mean(pf_vec[target_size-3:target_size]) > 0.98:
            break            

    print('total time = ',time.time()-overall_start_time)
    
    return L_configs,pf_vec,target_size,np.exp((np.cumsum(np.log(pf_vec[2:target_size])))[-1])


# Given a conc_pattern, run FFS code for each structure and report nucleation rate
def analyze_pattern(pattern_filename,Gse):
    cvar = 0.001  # Sets the target accuracy. 0.001 might be ~ 1.2x accurate when runs are ~15 secs long. Less accurate for longer runs.

    hcv,acv,mcv,cv = TST.load_concentration_pattern(pattern_filename,smaps)
    
    params["conc_vec"] = hcv
    L_configs,pf_vec,target_size,nuc_rate_h = prop_forward_constvar(Gse,100,cvar,params)
    print(nuc_rate_h,' M/s')
    
    params["conc_vec"] = acv
    L_configs,pf_vec,target_size,nuc_rate_a = prop_forward_constvar(Gse,100,cvar,params)
    print(nuc_rate_a,' M/s')
    
    params["conc_vec"] = mcv
    L_configs,pf_vec,target_size,nuc_rate_m = prop_forward_constvar(Gse,100,cvar,params)
    print(nuc_rate_m,' M/s')
    
    return [nuc_rate_h,nuc_rate_a,nuc_rate_m]
    

p = {'conc_vec': np.ones(918)*1000e-9}
p['conc_vec'][0] = 0
p.update(params)

#a = prop_forward_constvar(10.5, 3, 0.4, p)

# Actual runs

np.load('myApat.npy');

#TST.show_conc_patterns('myApat.npy',smaps)

analyze_pattern('myApat.npy',10.5)
# Out:
# z = 9.663232791663145e-07
# total time =  0.016473770141601562
# 7.159360234623297e-10  M/s
# z = 1.3814363061431772e-06
# total time =  0.014650106430053711
# 2.976517930071033e-09  M/s
# z = 9.82184204886441e-07
# total time =  0.011812448501586914
# 1.0855035074778992e-09  M/s
# [7.159360234623297e-10, 2.976517930071033e-09, 1.0855035074778992e-09]

# %%
# Out:
# Found conf after 434
# Found conf after 2319
# Found conf after 2338
# Found conf after 2392
# Found conf after 2463
# Found conf after 2549
# Found conf after 5101
# Found conf after 5429
# Found conf after 5657
# Found conf after 6999
# Found conf after 7048
# Found conf after 7827
# Found conf after 9780
# Found conf after 10245
# Found conf after 10558
# Found conf after 11331
# Found conf after 13148
# Found conf after 14594
# Found conf after 15017
# Found conf after 15068
# Found conf after 15409
# Found conf after 15753
# Found conf after 17072
# Found conf after 17192
# Found conf after 17715
# Found conf after 19201
# Found conf after 21767
# Found conf after 24731
# Found conf after 25411
# Found conf after 25417
# Found conf after 26018
# Found conf after 26534
# Found conf after 26857
# Found conf after 27143
# Found conf after 27545
# Found conf after 31526
# Found conf after 31563
# Found conf after 33645
# Found conf after 34150
# Found conf after 34233
# Found conf after 36201
# Found conf after 39237
# Found conf after 39856
# Found conf after 40920
# Found conf after 41041
# Found conf after 41857
# Found conf after 41882
# Found conf after 42449
# Found conf after 44281
# Found conf after 45018
# Found conf after 45509
# Found conf after 45931
# Found conf after 49209
# Found conf after 50220
# Found conf after 50313
# Found conf after 50745
# Found conf after 51848
# Found conf after 52469
# Found conf after 52837
# Found conf after 55499
# Found conf after 56105
# Found conf after 56703
# Found conf after 61218
# Found conf after 61416
# Found conf after 63489
# Found conf after 64360
# Found conf after 66256
# Found conf after 66464
# Found conf after 66967
# Found conf after 66988
# Found conf after 69047
# Found conf after 69695
# Found conf after 71227
# Found conf after 71557
# Found conf after 71648
# Found conf after 71773
# Found conf after 72488
# Found conf after 73037
# Found conf after 73208
# Found conf after 75990
# Found conf after 76457
# Found conf after 76909
# Found conf after 76935
# Found conf after 76976
# Found conf after 78633
# Found conf after 79110
# Found conf after 80368
# Found conf after 80667
# Found conf after 80923
# Found conf after 80931
# Found conf after 82166
# Found conf after 83568
# Found conf after 84972
# Found conf after 86404
# Found conf after 89087
# Found conf after 89701
# Found conf after 90348
# Found conf after 91189
# Found conf after 91486
# Found conf after 92562
# z = 9.663232791663145e-07
# total time =  0.015623331069946289
# 5.704851040596911e-10  M/s
# Found conf after 294
# Found conf after 1016
# Found conf after 1289
# Found conf after 1441
# Found conf after 1527
# Found conf after 1866
# Found conf after 1893
# Found conf after 2054
# Found conf after 2429
# Found conf after 2479
# Found conf after 2529
# Found conf after 2545
# Found conf after 2600
# Found conf after 2609
# Found conf after 2689
# Found conf after 2784
# Found conf after 2851
# Found conf after 3756
# Found conf after 3970
# Found conf after 4253
# Found conf after 4590
# Found conf after 5511
# Found conf after 6000
# Found conf after 6520
# Found conf after 6533
# Found conf after 6788
# Found conf after 6849
# Found conf after 6901
# Found conf after 6920
# Found conf after 7223
# Found conf after 7497
# Found conf after 8077
# Found conf after 8093
# Found conf after 8104
# Found conf after 8218
# Found conf after 8893
# Found conf after 8963
# Found conf after 9069
# Found conf after 9103
# Found conf after 9365
# Found conf after 9986
# Found conf after 10042
# Found conf after 10045
# Found conf after 10157
# Found conf after 10251
# Found conf after 10493
# Found conf after 11002
# Found conf after 11656
# Found conf after 11834
# Found conf after 11916
# Found conf after 12057
# Found conf after 12112
# Found conf after 12629
# Found conf after 12729
# Found conf after 12930
# Found conf after 12984
# Found conf after 13255
# Found conf after 13539
# Found conf after 13802
# Found conf after 13966
# Found conf after 14327
# Found conf after 14355
# Found conf after 14793
# Found conf after 14914
# Found conf after 15007
# Found conf after 15029
# Found conf after 16176
# Found conf after 16527
# Found conf after 16595
# Found conf after 16736
# Found conf after 17454
# Found conf after 17964
# Found conf after 18165
# Found conf after 18324
# Found conf after 18601
# Found conf after 18675
# Found conf after 19611
# Found conf after 20600
# Found conf after 21288
# Found conf after 21291
# Found conf after 21396
# Found conf after 21702
# Found conf after 22449
# Found conf after 22669
# Found conf after 22909
# Found conf after 23115
# Found conf after 23213
# Found conf after 23242
# Found conf after 23243
# Found conf after 24775
# Found conf after 25531
# Found conf after 25759
# Found conf after 25979
# Found conf after 26238
# Found conf after 26441
# Found conf after 26713
# Found conf after 26767
# Found conf after 26974
# Found conf after 27085
# Found conf after 27306
# z = 1.3814363061431772e-06
# total time =  0.015428543090820312
# 2.791868522463442e-09  M/s
# Found conf after 80
# Found conf after 1661
# Found conf after 1684
# Found conf after 2293
# Found conf after 2474
# Found conf after 3601
# Found conf after 4812
# Found conf after 5179
# Found conf after 5524
# Found conf after 5963
# Found conf after 6997
# Found conf after 7128
# Found conf after 7261
# Found conf after 7595
# Found conf after 7969
# Found conf after 8518
# Found conf after 8715
# Found conf after 8820
# Found conf after 9444
# Found conf after 9804
# Found conf after 10738
# Found conf after 10827
# Found conf after 13350
# Found conf after 14459
# Found conf after 15487
# Found conf after 16235
# Found conf after 16909
# Found conf after 17636
# Found conf after 17769
# Found conf after 17915
# Found conf after 19654
# Found conf after 20306
# Found conf after 20642
# Found conf after 20693
# Found conf after 20871
# Found conf after 20904
# Found conf after 21175
# Found conf after 21675
# Found conf after 22161
# Found conf after 22770
# Found conf after 23364
# Found conf after 24060
# Found conf after 24615
# Found conf after 25590
# Found conf after 26342
# Found conf after 26868
# Found conf after 26917
# Found conf after 26919
# Found conf after 27216
# Found conf after 27523
# Found conf after 28496
# Found conf after 28643
# Found conf after 28967
# Found conf after 29270
# Found conf after 30090
# Found conf after 30870
# Found conf after 30955
# Found conf after 31005
# Found conf after 31510
# Found conf after 31940
# Found conf after 32106
# Found conf after 32512
# Found conf after 33696
# Found conf after 33740
# Found conf after 34923
# Found conf after 36108
# Found conf after 37522
# Found conf after 38416
# Found conf after 39235
# Found conf after 40076
# Found conf after 40101
# Found conf after 40553
# Found conf after 40779
# Found conf after 40953
# Found conf after 45431
# Found conf after 46064
# Found conf after 46620
# Found conf after 46805
# Found conf after 48709
# Found conf after 49088
# Found conf after 49464
# Found conf after 49908
# Found conf after 50191
# Found conf after 50677
# Found conf after 50812
# Found conf after 51082
# Found conf after 51368
# Found conf after 51710
# Found conf after 52183
# Found conf after 52194
# Found conf after 52940
# Found conf after 52998
# Found conf after 53006
# Found conf after 53308
# Found conf after 53698
# Found conf after 54249
# Found conf after 54355
# Found conf after 54982
# Found conf after 55188
# Found conf after 56078
# z = 9.82184204886441e-07
# total time =  0.012058258056640625
# 9.477961077659395e-10  M/s
# [5.704851040596911e-10, 2.791868522463442e-09, 9.477961077659395e-10]
